# %% [markdown]
# ### 单天检验

# %%
import pandas as pd
import numpy as np
import os
import csv

class Dataconfirm():
    
    def __init__(self, newfolder, oldfolder):
        self.newfolder = newfolder
        self.oldfolder = oldfolder
        
    def checkdata(self):  #每次调取这个函数是一年的
        
        new_path = self.newfolder  #包含年份的一整条绝对路径
        old_path = self.oldfolder

        # year = new_path[ new_path.rindex( '/' ) + 1 : len( new_path ) ] #截取年份
        
        new_timelist = os.listdir(new_path)   #仅遍历获取该日期下所有的时间文件夹名字的集合
        old_timelist = os.listdir(old_path)
        
        AllNewPath = []  #筛选过的完整路径集合
        AllOldPath = []

        for time_i in new_timelist:
            if os.path.exists(old_path + '/' + time_i) == True:
                AllNewPath.append(new_path + '/' + time_i) #保证两个list顺序一致
                AllOldPath.append(old_path + '/' + time_i)
            else:
                new_timelist.remove(time_i) #new_timelist里最后只包含两边都有文件的时间文件名集合,old_timelist也许仍有new里没有的时间
        
        
        os.system("pwd") #确认是从yuqin work出发
        os.system("mkdir -p 2020Compare")
        os.chdir("2020Compare")
        os.system("mkdir -p 0120")
        os.chdir("0120")
        os.system("pwd")
        
        headers = ['secucode', 'time', 'ratio', 'BidPriceAvgL10Twa', 'BidPriceAvgL5Twa', 'BidPriceAvgL3Twa', 'BidPrice', 'AskPrice', 'AskPriceAvgL3Twa', 'AskPriceAvgL5Twa', 'AskPriceAvgL10Twa', 'BidPriceVwaL10Twa', 'BidPriceVwaL5Twa', 'BidPriceVwaL3Twa', 'AskPriceVwaL3Twa', 'AskPriceVwaL5Twa', 'AskPriceVwaL10Twa', 'BidPriceAtL10Twa', 'BidPriceAtL5Twa', 'BidPriceAtL3Twa', 'AskPriceAtL3Twa', 'AskPriceAtL5Twa', 'AskPriceAtL10Twa', 'PreClosePrice', 'BidPriceAtL1Vwa', 'AskPriceAtL1Vwa', 'BidPriceAvgL3Vwa', 'AskPriceAvgL3Vwa', 'BidPriceAvgL5Vwa', 'AskPriceAvgL5Vwa', 'BidPriceAvgL10Vwa', 'AskPriceAvgL10Vwa']
        OneDay_logname = "20201231.csv"
        OneDay_log = open(OneDay_logname , 'w')
        log = csv.DictWriter(OneDay_log, headers)
        log.writeheader()
        
        for n in range(len(AllNewPath)):
            
            getpath_new = AllNewPath[n]
            getpath_old = AllOldPath[n]

            print(getpath_new)
            print(getpath_old)
            
            new_5min = pd.read_csv(getpath_new)
            old_5min = pd.read_csv(getpath_old)
        
            new_colname = list(new_5min.columns)
            new_secucode = list(new_5min.iloc[:,0])
            new_puredata = np.array(new_5min.iloc[:,1:], dtype = float)
            old_colname = list(old_5min.columns)
            old_secucode = list(old_5min.iloc[:,0])
            old_puredata = np.array(old_5min.iloc[:,1:], dtype = float)

            new_index = []
            old_index = []
            
            d = getpath_new
            time = d[ d.rindex( '/' ) + 1 : len( d ) ] 
            withoutLastStr = d[ 0 : d.rindex( '/' ) ]
            date= withoutLastStr[ withoutLastStr.rindex( '/' ) + 1 : len( withoutLastStr ) ]
            year = date[0:4]
            
            for i in range(len(new_secucode)):
                temp = np.where(np.asarray(old_secucode) == new_secucode[i])[0]
                if (len(temp)) > 0:

                    BidPriceAvgL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL10Twa')[0][0] - 1]
                    BidPriceAvgL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL5Twa')[0][0] - 1]
                    BidPriceAvgL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL3Twa')[0][0] - 1]
                    BidPrice = old_puredata[temp, np.where(np.asarray(old_colname) == 'BidPrice')[0][0] - 1]
                    AskPrice = old_puredata[temp, np.where(np.asarray(old_colname) == 'AskPrice')[0][0] - 1]
                    AskPriceAvgL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL3Twa')[0][0] - 1]
                    AskPriceAvgL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL5Twa')[0][0] - 1]
                    AskPriceAvgL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL10Twa')[0][0] - 1]

                    BidPriceVwaL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceVwaL10Twa')[0][0] - 1]
                    BidPriceVwaL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceVwaL5Twa')[0][0] - 1]
                    BidPriceVwaL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceVwaL3Twa')[0][0] - 1]
                    AskPriceVwaL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceVwaL3Twa')[0][0] - 1]
                    AskPriceVwaL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceVwaL5Twa')[0][0] - 1]
                    AskPriceVwaL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceVwaL10Twa')[0][0] - 1]

                    BidPriceAtL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAtL10Twa')[0][0] - 1]
                    BidPriceAtL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAtL5Twa')[0][0] - 1]
                    BidPriceAtL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAtL3Twa')[0][0] - 1]
                    AskPriceAtL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAtL3Twa')[0][0] - 1]
                    AskPriceAtL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAtL5Twa')[0][0] - 1]
                    AskPriceAtL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAtL10Twa')[0][0] - 1]

                    PreClosePrice = new_puredata[i, np.where(np.asarray(new_colname) == 'PreClosePrice')[0][0] - 1]
                    BidPriceAtL1Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAtL1Vwa')[0][0] - 1]
                    AskPriceAtL1Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAtL1Vwa')[0][0] - 1]
                    BidPriceAvgL3Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL3Vwa')[0][0] - 1]
                    AskPriceAvgL3Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL3Vwa')[0][0] - 1]
                    BidPriceAvgL5Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL5Vwa')[0][0] - 1]
                    AskPriceAvgL5Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL5Vwa')[0][0] - 1]
                    BidPriceAvgL10Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL10Vwa')[0][0] - 1]
                    AskPriceAvgL10Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL10Vwa')[0][0] - 1]
                    nWeightedAvgBidPriceAvg = new_puredata[i, np.where(np.asarray(new_colname) == 'nWeightedAvgBidPriceAvg')[0][0] - 1]
                    nWeightedAvgAskPriceAvg = new_puredata[i, np.where(np.asarray(new_colname) == 'nWeightedAvgAskPriceAvg')[0][0] - 1]

                    BidVolSumL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidVolSumL3Twa')[0][0] - 1]
                    BidVolSumL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidVolSumL5Twa')[0][0] - 1]
                    BidVolSumL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidVolSumL10Twa')[0][0] - 1]
                    
                    AskVolSumL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskVolSumL3Twa')[0][0] - 1]
                    AskVolSumL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskVolSumL5Twa')[0][0] - 1]
                    AskVolSumL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskVolSumL10Twa')[0][0] - 1]
                    
                    BidVolume = old_puredata[temp, np.where(np.asarray(old_colname) == 'BidVolume')[0][0] - 1]
                    AskVolume = old_puredata[temp, np.where(np.asarray(old_colname) == 'AskVolume')[0][0] - 1]                    
                    
                    new_index.append(i)
                    old_index.append(temp[0])

                        
                    if not ((BidPriceAvgL10Twa <= BidPriceAvgL5Twa) & (BidPriceAvgL5Twa <= BidPriceAvgL3Twa) & (
                            BidPriceAvgL3Twa <= BidPrice) & (BidPrice <= AskPrice) & (AskPrice <= AskPriceAvgL3Twa) & (
                            AskPriceAvgL3Twa <= AskPriceAvgL5Twa) & (AskPriceAvgL5Twa <= AskPriceAvgL10Twa)):
                        if (np.isnan(BidPriceAvgL10Twa) == True) or (np.isnan(BidPriceAvgL5Twa) == True) or (np.isnan(BidPriceAvgL3Twa) == True) or (np.isnan(BidPrice) == True) or (np.isnan(AskPrice) == True) or (np.isnan(AskPriceAvgL3Twa) == True) or(np.isnan(AskPriceAvgL5Twa) == True) or (np.isnan(AskPriceAvgL10Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAvgL10Twa':str(BidPriceAvgL10Twa), 'BidPriceAvgL5Twa':str(BidPriceAvgL5Twa), 'BidPriceAvgL3Twa':str(BidPriceAvgL3Twa), 'BidPrice':str(BidPrice[0]), 'AskPrice':str(AskPrice[0]),  'AskPriceAvgL3Twa':str(AskPriceAvgL3Twa), 'AskPriceAvgL5Twa':str(AskPriceAvgL5Twa), 'AskPriceAvgL10Twa':str(AskPriceAvgL10Twa)})
                        continue

                    if not ((BidPriceVwaL10Twa <= BidPriceVwaL5Twa) & (BidPriceVwaL5Twa <= BidPriceVwaL3Twa) & (
                            BidPriceVwaL3Twa <= BidPrice) & (BidPrice <= AskPrice) & (AskPrice <= AskPriceVwaL3Twa) & (
                            AskPriceVwaL3Twa <= AskPriceVwaL5Twa) & (AskPriceVwaL5Twa <= AskPriceVwaL10Twa)):
                        if (np.isnan(BidPriceVwaL10Twa) == True) or (np.isnan(BidPriceVwaL5Twa) == True) or (np.isnan(BidPriceVwaL3Twa) == True) or (np.isnan(BidPrice) == True) or (np.isnan(AskPrice) == True) or (np.isnan(AskPriceVwaL3Twa) == True) or(np.isnan(AskPriceVwaL5Twa) == True) or (np.isnan(AskPriceVwaL10Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceVwaL10Twa':str(BidPriceVwaL10Twa), 'BidPriceVwaL5Twa':str(BidPriceVwaL5Twa), 'BidPriceVwaL3Twa':str(BidPriceVwaL3Twa), 'BidPrice':str(BidPrice[0]), 'AskPrice':str(AskPrice[0]),  'AskPriceVwaL3Twa':str(AskPriceVwaL3Twa), 'AskPriceVwaL5Twa':str(AskPriceVwaL5Twa), 'AskPriceVwaL10Twa':str(AskPriceVwaL10Twa)})
                        continue

                    if not ((BidPriceAtL10Twa <= BidPriceAtL5Twa) & (BidPriceAtL5Twa <= BidPriceAtL3Twa) & (
                            BidPriceAtL3Twa <= BidPrice) & (BidPrice <= AskPrice) & (AskPrice <= AskPriceAtL3Twa) & (
                            AskPriceAtL3Twa <= AskPriceAtL5Twa) & (AskPriceAtL5Twa <= AskPriceAtL10Twa)):
                        if (np.isnan(BidPriceAtL10Twa) == True) or (np.isnan(BidPriceAtL5Twa) == True) or (np.isnan(BidPriceAtL3Twa) == True) or (np.isnan(BidPrice) == True) or (np.isnan(AskPrice) == True) or (np.isnan(AskPriceAtL3Twa) == True) or(np.isnan(AskPriceAtL5Twa) == True) or (np.isnan(AskPriceAtL10Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL10Twa':str(BidPriceAtL10Twa), 'BidPriceAtL5Twa':str(BidPriceAtL5Twa), 'BidPriceAtL3Twa':str(BidPriceAtL3Twa), 'BidPrice':str(BidPrice[0]), 'AskPrice':str(AskPrice[0]), 'AskPriceAtL3Twa':str(AskPriceAtL3Twa), 'AskPriceAtL5Twa':str(AskPriceAtL5Twa), 'AskPriceAtL10Twa':str(AskPriceAtL10Twa)})                        
                        continue

                        
                    if not (BidPriceAtL3Twa <= BidPriceAvgL3Twa):
                        if (np.isnan(BidPriceAtL3Twa) == True) or (np.isnan(BidPriceAvgL3Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL3Twa':str(BidPriceAtL3Twa), 'BidPriceAvgL3Twa':str(BidPriceAvgL3Twa)})
                        continue
                    if not (BidPriceAtL5Twa <= BidPriceAvgL5Twa):
                        if (np.isnan(BidPriceAtL5Twa) == True) or (np.isnan(BidPriceAvgL5Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL5Twa':str(BidPriceAtL5Twa), 'BidPriceAvgL5Twa':str(BidPriceAvgL5Twa)})
                        continue
                    if not (BidPriceAtL10Twa <= BidPriceAvgL10Twa):
                        if (np.isnan(BidPriceAtL10Twa) == True) or (np.isnan(BidPriceAvgL10Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL10Twa':str(BidPriceAtL10Twa), 'BidPriceAvgL10Twa':str(BidPriceAvgL10Twa)})
                        continue
                        
                        
                    if not (BidPriceAtL3Twa <= BidPriceVwaL3Twa):
                        if (np.isnan(BidPriceAtL3Twa) == True) or (np.isnan(BidPriceVwaL3Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL3Twa':str(BidPriceAtL3Twa),'BidPriceVwaL3Twa':str(BidPriceVwaL3Twa)})
                        continue
                    if not (BidPriceAtL5Twa <= BidPriceVwaL5Twa):
                        if (np.isnan(BidPriceAtL5Twa) == True) or (np.isnan(BidPriceVwaL5Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL5Twa':str(BidPriceAtL5Twa), 'BidPriceVwaL5Twa':str(BidPriceVwaL5Twa)})
                        continue
                    if not (BidPriceAtL10Twa <= BidPriceVwaL10Twa):
                        if (np.isnan(BidPriceAtL10Twa) == True) or (np.isnan(BidPriceVwaL10Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL10Twa':str(BidPriceAtL10Twa), 'BidPriceVwaL10Twa':str(BidPriceVwaL10Twa)})
                        continue


                    if not (AskPriceAtL3Twa >= AskPriceAvgL3Twa):
                        if (np.isnan(AskPriceAtL3Twa) == True) or (np.isnan(AskPriceAvgL3Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL3Twa':str(AskPriceAtL3Twa), 'AskPriceAvgL3Twa':str(AskPriceAvgL3Twa)})
                        continue
                    if not (AskPriceAtL5Twa >= AskPriceAvgL5Twa):
                        if (np.isnan(AskPriceAtL5Twa) == True) or (np.isnan(AskPriceAvgL5Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL5Twa':str(AskPriceAtL5Twa), 'AskPriceAvgL5Twa':str(AskPriceAvgL5Twa)})
                        continue
                    if not (AskPriceAtL10Twa >= AskPriceAvgL10Twa):
                        if (np.isnan(AskPriceAtL10Twa) == True) or (np.isnan(AskPriceAvgL10Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL10Twa':str(AskPriceAtL10Twa), 'AskPriceAvgL10Twa':str(AskPriceAvgL10Twa)})
                        continue
                        
                    if not (AskPriceAtL3Twa >= AskPriceVwaL3Twa):
                        if (np.isnan(AskPriceAtL3Twa) == True) or (np.isnan(AskPriceVwaL3Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL3Twa':str(AskPriceAtL3Twa), 'AskPriceVwaL3Twa':str(AskPriceVwaL3Twa)})
                        continue
                    if not (AskPriceAtL5Twa >= AskPriceVwaL5Twa):
                        if (np.isnan(AskPriceAtL5Twa) == True) or (np.isnan(AskPriceVwaL5Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL5Twa':str(AskPriceAtL5Twa), 'AskPriceVwaL5Twa':str(AskPriceVwaL5Twa)})
                        continue
                    if not (AskPriceAtL10Twa >= AskPriceVwaL10Twa):
                        if (np.isnan(AskPriceAtL5Twa) == True) or (np.isnan(AskPriceVwaL5Twa) == True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL10Twa':str(AskPriceAtL10Twa), 'AskPriceVwaL10Twa':str(AskPriceVwaL10Twa)})
                        continue

                    m1 = 0.8
                    m2 = 1.2
                    if not ((PreClosePrice * m1 <= BidPriceAtL1Vwa) & (BidPriceAtL1Vwa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAtL1Vwa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAtL1Vwa/PreClosePrice), 'BidPriceAtL1Vwa':str(BidPriceAtL1Vwa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAtL1Vwa) & (AskPriceAtL1Vwa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAtL1Vwa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAtL1Vwa/PreClosePrice), 'AskPriceAtL1Vwa':str(AskPriceAtL1Vwa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAtL3Twa) & (BidPriceAtL3Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAtL3Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAtL3Twa/PreClosePrice), 'BidPriceAtL3Twa':str(BidPriceAtL3Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAvgL3Twa) & (BidPriceAvgL3Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAvgL3Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL3Twa/PreClosePrice), 'BidPriceAvgL3Twa':str(BidPriceAvgL3Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAvgL3Vwa) & (BidPriceAvgL3Vwa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAvgL3Vwa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL3Vwa/PreClosePrice), 'BidPriceAvgL3Vwa':str(BidPriceAvgL3Vwa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceVwaL3Twa) & (BidPriceVwaL3Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceVwaL3Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceVwaL3Twa/PreClosePrice), 'BidPriceVwaL3Twa':str(BidPriceVwaL3Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAtL3Twa) & (AskPriceAtL3Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAtL3Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAtL3Twa/PreClosePrice), 'AskPriceAtL3Twa':str(AskPriceAtL3Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAvgL3Twa) & (AskPriceAvgL3Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAvgL3Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL3Twa/PreClosePrice), 'AskPriceAvgL3Twa':str(AskPriceAvgL3Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAvgL3Vwa) & (AskPriceAvgL3Vwa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAvgL3Vwa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL3Vwa/PreClosePrice), 'AskPriceAvgL3Vwa':str(AskPriceAvgL3Vwa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceVwaL3Twa) & (AskPriceVwaL3Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceVwaL3Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceVwaL3Twa/PreClosePrice), 'AskPriceVwaL3Twa':str(AskPriceVwaL3Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAtL5Twa) & (BidPriceAtL5Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAtL5Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAtL5Twa/PreClosePrice), 'BidPriceAtL5Twa':str(BidPriceAtL5Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAvgL5Twa) & (BidPriceAvgL5Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAvgL5Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL5Twa/PreClosePrice), 'BidPriceAvgL5Twa':str(BidPriceAvgL5Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAvgL5Vwa) & (BidPriceAvgL5Vwa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAvgL5Vwa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL5Vwa/PreClosePrice), 'BidPriceAvgL5Vwa':str(BidPriceAvgL5Vwa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceVwaL5Twa) & (BidPriceVwaL5Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceVwaL5Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceVwaL5Twa/PreClosePrice), 'BidPriceVwaL5Twa':str(BidPriceVwaL5Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAtL5Twa) & (AskPriceAtL5Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAtL5Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAtL5Twa/PreClosePrice), 'AskPriceAtL5Twa':str(AskPriceAtL5Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAvgL5Twa) & (AskPriceAvgL5Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAvgL5Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL5Twa/PreClosePrice), 'AskPriceAvgL5Twa':str(AskPriceAvgL5Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAvgL5Vwa) & (AskPriceAvgL5Vwa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAvgL5Vwa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL5Vwa/PreClosePrice), 'AskPriceAvgL5Vwa':str(AskPriceAvgL5Vwa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceVwaL5Twa) & (AskPriceVwaL5Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceVwaL5Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceVwaL5Twa/PreClosePrice), 'AskPriceVwaL5Twa':str(AskPriceVwaL5Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAtL10Twa) & (BidPriceAtL10Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAtL10Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAtL10Twa/PreClosePrice), 'BidPriceAtL10Twa':str(BidPriceAtL10Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAvgL10Twa) & (BidPriceAvgL10Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAvgL10Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL10Twa/PreClosePrice), 'BidPriceAvgL10Twa':str(BidPriceAvgL10Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceAvgL10Vwa) & (BidPriceAvgL10Vwa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceAvgL10Vwa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL10Vwa/PreClosePrice), 'BidPriceAvgL10Vwa':str(BidPriceAvgL10Vwa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= BidPriceVwaL10Twa) & (BidPriceVwaL10Twa <= PreClosePrice * m2)):
                        if (np.isnan(BidPriceVwaL10Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceVwaL10Twa/PreClosePrice), 'BidPriceVwaL10Twa':str(BidPriceVwaL10Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAtL10Twa) & (AskPriceAtL10Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAtL10Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAtL10Twa/PreClosePrice), 'AskPriceAtL10Twa':str(AskPriceAtL10Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAvgL10Twa) & (AskPriceAvgL10Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAvgL10Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL10Twa/PreClosePrice), 'AskPriceAvgL10Twa':str(AskPriceAvgL10Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceAvgL10Vwa) & (AskPriceAvgL10Vwa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceAvgL10Vwa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL10Vwa/PreClosePrice), 'AskPriceAvgL10Vwa':str(AskPriceAvgL10Vwa), 'PreClosePrice':str(PreClosePrice)})
                        continue
                    if not ((PreClosePrice * m1 <= AskPriceVwaL10Twa) & (AskPriceVwaL10Twa <= PreClosePrice * m2)):
                        if (np.isnan(AskPriceVwaL10Twa)==True):
                            continue
                        log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceVwaL10Twa/PreClosePrice), 'AskPriceVwaL10Twa':str(AskPriceVwaL10Twa), 'PreClosePrice':str(PreClosePrice)})
                        continue
            os.chdir("../..")
            
        print('OneDay_log done')
            
            
def main():
    
    for date in range(20210819, 20210822):
        
        newfolder = "/dat/all_till20201230/Equity/CN/marketdata/level2summary/5min/data/2020/" + str(date)
        oldfolder= "/dat/all_till20201230/Equity/CN/5min/data/2020/" + str(date)
    print(newfolder)
    print(oldfolder)
    
    result = Dataconfirm(newfolder, oldfolder)
    result.checkdata()
    
if __name__ == '__main__':
    
    main()

# %% [markdown]
# ### 日线

# %%
import pandas as pd
import numpy as np
import os
import csv

class Dataconfirm():
    
    def __init__(self, newfolder, oldfolder, date):
        self.newfolder = newfolder
        self.oldfolder = oldfolder
        self.date = date
        
    def checkdata(self):  #每次调取这个函数是一年的
        
        new_path = self.newfolder  #包含年份的一整条绝对路径
        old_path = self.oldfolder
        
        os.system("pwd") #确认是从yuqin work出发
        os.system("mkdir -p 2020Compare")
        os.chdir("2020Compare")
        os.system("mkdir -p 0120")
        os.chdir("0120")
        os.system("mkdir -p check")
        os.chdir("check")
        os.system("pwd")
        
        headers = ['secucode', 'time', 'ratio', 'BidPriceAvgL10Twa', 'BidPriceAvgL5Twa', 'BidPriceAvgL3Twa', 'BidPrice', 'AskPrice', 'AskPriceAvgL3Twa', 'AskPriceAvgL5Twa', 'AskPriceAvgL10Twa', 'BidPriceVwaL10Twa', 'BidPriceVwaL5Twa', 'BidPriceVwaL3Twa', 'AskPriceVwaL3Twa', 'AskPriceVwaL5Twa', 'AskPriceVwaL10Twa', 'BidPriceAtL10Twa', 'BidPriceAtL5Twa', 'BidPriceAtL3Twa', 'AskPriceAtL3Twa', 'AskPriceAtL5Twa', 'AskPriceAtL10Twa', 'PreClosePrice', 'BidPriceAtL1Vwa', 'AskPriceAtL1Vwa', 'BidPriceAvgL3Vwa', 'AskPriceAvgL3Vwa', 'BidPriceAvgL5Vwa', 'AskPriceAvgL5Vwa', 'BidPriceAvgL10Vwa', 'AskPriceAvgL10Vwa']
        OneDay_log = open("/home/yuqin/work/2020Compare/0120/check/%s.csv" %(self.date), "w")
        log = csv.DictWriter(OneDay_log, headers)
        log.writeheader()
        
        ############
            
        getpath_new = new_path
        getpath_old = old_path

        print(getpath_new)
        print(getpath_old)
            
        new_5min = pd.read_csv(getpath_new)
        old_5min = pd.read_csv(getpath_old)
        
        new_colname = list(new_5min.columns)
        new_secucode = list(new_5min.iloc[:,0])
        new_puredata = np.array(new_5min.iloc[:,1:], dtype = float)
        old_colname = list(old_5min.columns)
        old_secucode = list(old_5min.iloc[:,0])
        old_puredata = np.array(old_5min.iloc[:,1:], dtype = float)

        new_index = []
        old_index = []
            
        time = 'OneDay'
            
        for i in range(len(new_secucode)):
            temp = np.where(np.asarray(old_secucode) == new_secucode[i])[0]
            if (len(temp)) > 0:

                BidPriceAvgL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL10Twa')[0][0] - 1]
                BidPriceAvgL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL5Twa')[0][0] - 1]
                BidPriceAvgL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL3Twa')[0][0] - 1]
                BidPrice = old_puredata[temp, np.where(np.asarray(old_colname) == 'BidPrice')[0][0] - 1]
                AskPrice = old_puredata[temp, np.where(np.asarray(old_colname) == 'AskPrice')[0][0] - 1]
                AskPriceAvgL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL3Twa')[0][0] - 1]
                AskPriceAvgL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL5Twa')[0][0] - 1]
                AskPriceAvgL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL10Twa')[0][0] - 1]

                BidPriceVwaL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceVwaL10Twa')[0][0] - 1]
                BidPriceVwaL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceVwaL5Twa')[0][0] - 1]
                BidPriceVwaL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceVwaL3Twa')[0][0] - 1]
                AskPriceVwaL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceVwaL3Twa')[0][0] - 1]
                AskPriceVwaL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceVwaL5Twa')[0][0] - 1]
                AskPriceVwaL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceVwaL10Twa')[0][0] - 1]

                BidPriceAtL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAtL10Twa')[0][0] - 1]
                BidPriceAtL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAtL5Twa')[0][0] - 1]
                BidPriceAtL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAtL3Twa')[0][0] - 1]
                AskPriceAtL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAtL3Twa')[0][0] - 1]
                AskPriceAtL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAtL5Twa')[0][0] - 1]
                AskPriceAtL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAtL10Twa')[0][0] - 1]

                PreClosePrice = new_puredata[i, np.where(np.asarray(new_colname) == 'PreClosePrice')[0][0] - 1]
                BidPriceAtL1Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAtL1Vwa')[0][0] - 1]
                AskPriceAtL1Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAtL1Vwa')[0][0] - 1]
                BidPriceAvgL3Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL3Vwa')[0][0] - 1]
                AskPriceAvgL3Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL3Vwa')[0][0] - 1]
                BidPriceAvgL5Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL5Vwa')[0][0] - 1]
                AskPriceAvgL5Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL5Vwa')[0][0] - 1]
                BidPriceAvgL10Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidPriceAvgL10Vwa')[0][0] - 1]
                AskPriceAvgL10Vwa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskPriceAvgL10Vwa')[0][0] - 1]
                nWeightedAvgBidPriceAvg = new_puredata[i, np.where(np.asarray(new_colname) == 'nWeightedAvgBidPriceAvg')[0][0] - 1]
                nWeightedAvgAskPriceAvg = new_puredata[i, np.where(np.asarray(new_colname) == 'nWeightedAvgAskPriceAvg')[0][0] - 1]

                BidVolSumL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidVolSumL3Twa')[0][0] - 1]
                BidVolSumL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidVolSumL5Twa')[0][0] - 1]
                BidVolSumL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'BidVolSumL10Twa')[0][0] - 1]
                    
                AskVolSumL3Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskVolSumL3Twa')[0][0] - 1]
                AskVolSumL5Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskVolSumL5Twa')[0][0] - 1]
                AskVolSumL10Twa = new_puredata[i, np.where(np.asarray(new_colname) == 'AskVolSumL10Twa')[0][0] - 1]
                    
                BidVolume = old_puredata[temp, np.where(np.asarray(old_colname) == 'BidVolume')[0][0] - 1]
                AskVolume = old_puredata[temp, np.where(np.asarray(old_colname) == 'AskVolume')[0][0] - 1]                    
                    
                new_index.append(i)
                old_index.append(temp[0])

                        
                if not ((BidPriceAvgL10Twa <= BidPriceAvgL5Twa) & (BidPriceAvgL5Twa <= BidPriceAvgL3Twa) & (
                        BidPriceAvgL3Twa <= BidPrice) & (BidPrice <= AskPrice) & (AskPrice <= AskPriceAvgL3Twa) & (
                        AskPriceAvgL3Twa <= AskPriceAvgL5Twa) & (AskPriceAvgL5Twa <= AskPriceAvgL10Twa)):
                    if (np.isnan(BidPriceAvgL10Twa) == True) or (np.isnan(BidPriceAvgL5Twa) == True) or (np.isnan(BidPriceAvgL3Twa) == True) or (np.isnan(BidPrice) == True) or (np.isnan(AskPrice) == True) or (np.isnan(AskPriceAvgL3Twa) == True) or(np.isnan(AskPriceAvgL5Twa) == True) or (np.isnan(AskPriceAvgL10Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAvgL10Twa':str(BidPriceAvgL10Twa), 'BidPriceAvgL5Twa':str(BidPriceAvgL5Twa), 'BidPriceAvgL3Twa':str(BidPriceAvgL3Twa), 'BidPrice':str(BidPrice[0]), 'AskPrice':str(AskPrice[0]),  'AskPriceAvgL3Twa':str(AskPriceAvgL3Twa), 'AskPriceAvgL5Twa':str(AskPriceAvgL5Twa), 'AskPriceAvgL10Twa':str(AskPriceAvgL10Twa)})
                    continue

                if not ((BidPriceVwaL10Twa <= BidPriceVwaL5Twa) & (BidPriceVwaL5Twa <= BidPriceVwaL3Twa) & (
                        BidPriceVwaL3Twa <= BidPrice) & (BidPrice <= AskPrice) & (AskPrice <= AskPriceVwaL3Twa) & (
                        AskPriceVwaL3Twa <= AskPriceVwaL5Twa) & (AskPriceVwaL5Twa <= AskPriceVwaL10Twa)):
                    if (np.isnan(BidPriceVwaL10Twa) == True) or (np.isnan(BidPriceVwaL5Twa) == True) or (np.isnan(BidPriceVwaL3Twa) == True) or (np.isnan(BidPrice) == True) or (np.isnan(AskPrice) == True) or (np.isnan(AskPriceVwaL3Twa) == True) or(np.isnan(AskPriceVwaL5Twa) == True) or (np.isnan(AskPriceVwaL10Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceVwaL10Twa':str(BidPriceVwaL10Twa), 'BidPriceVwaL5Twa':str(BidPriceVwaL5Twa), 'BidPriceVwaL3Twa':str(BidPriceVwaL3Twa), 'BidPrice':str(BidPrice[0]), 'AskPrice':str(AskPrice[0]),  'AskPriceVwaL3Twa':str(AskPriceVwaL3Twa), 'AskPriceVwaL5Twa':str(AskPriceVwaL5Twa), 'AskPriceVwaL10Twa':str(AskPriceVwaL10Twa)})
                    continue

                if not ((BidPriceAtL10Twa <= BidPriceAtL5Twa) & (BidPriceAtL5Twa <= BidPriceAtL3Twa) & (
                            BidPriceAtL3Twa <= BidPrice) & (BidPrice <= AskPrice) & (AskPrice <= AskPriceAtL3Twa) & (
                            AskPriceAtL3Twa <= AskPriceAtL5Twa) & (AskPriceAtL5Twa <= AskPriceAtL10Twa)):
                    if (np.isnan(BidPriceAtL10Twa) == True) or (np.isnan(BidPriceAtL5Twa) == True) or (np.isnan(BidPriceAtL3Twa) == True) or (np.isnan(BidPrice) == True) or (np.isnan(AskPrice) == True) or (np.isnan(AskPriceAtL3Twa) == True) or(np.isnan(AskPriceAtL5Twa) == True) or (np.isnan(AskPriceAtL10Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL10Twa':str(BidPriceAtL10Twa), 'BidPriceAtL5Twa':str(BidPriceAtL5Twa), 'BidPriceAtL3Twa':str(BidPriceAtL3Twa), 'BidPrice':str(BidPrice[0]), 'AskPrice':str(AskPrice[0]), 'AskPriceAtL3Twa':str(AskPriceAtL3Twa), 'AskPriceAtL5Twa':str(AskPriceAtL5Twa), 'AskPriceAtL10Twa':str(AskPriceAtL10Twa)})                        
                    continue

                        
                if not (BidPriceAtL3Twa <= BidPriceAvgL3Twa):
                    if (np.isnan(BidPriceAtL3Twa) == True) or (np.isnan(BidPriceAvgL3Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL3Twa':str(BidPriceAtL3Twa), 'BidPriceAvgL3Twa':str(BidPriceAvgL3Twa)})
                    continue
                if not (BidPriceAtL5Twa <= BidPriceAvgL5Twa):
                    if (np.isnan(BidPriceAtL5Twa) == True) or (np.isnan(BidPriceAvgL5Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL5Twa':str(BidPriceAtL5Twa), 'BidPriceAvgL5Twa':str(BidPriceAvgL5Twa)})
                    continue
                if not (BidPriceAtL10Twa <= BidPriceAvgL10Twa):
                    if (np.isnan(BidPriceAtL10Twa) == True) or (np.isnan(BidPriceAvgL10Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL10Twa':str(BidPriceAtL10Twa), 'BidPriceAvgL10Twa':str(BidPriceAvgL10Twa)})
                    continue
                        
                        
                if not (BidPriceAtL3Twa <= BidPriceVwaL3Twa):
                    if (np.isnan(BidPriceAtL3Twa) == True) or (np.isnan(BidPriceVwaL3Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL3Twa':str(BidPriceAtL3Twa),'BidPriceVwaL3Twa':str(BidPriceVwaL3Twa)})
                    continue
                if not (BidPriceAtL5Twa <= BidPriceVwaL5Twa):
                    if (np.isnan(BidPriceAtL5Twa) == True) or (np.isnan(BidPriceVwaL5Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL5Twa':str(BidPriceAtL5Twa), 'BidPriceVwaL5Twa':str(BidPriceVwaL5Twa)})
                    continue
                if not (BidPriceAtL10Twa <= BidPriceVwaL10Twa):
                    if (np.isnan(BidPriceAtL10Twa) == True) or (np.isnan(BidPriceVwaL10Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'BidPriceAtL10Twa':str(BidPriceAtL10Twa), 'BidPriceVwaL10Twa':str(BidPriceVwaL10Twa)})
                    continue


                if not (AskPriceAtL3Twa >= AskPriceAvgL3Twa):
                    if (np.isnan(AskPriceAtL3Twa) == True) or (np.isnan(AskPriceAvgL3Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL3Twa':str(AskPriceAtL3Twa), 'AskPriceAvgL3Twa':str(AskPriceAvgL3Twa)})
                    continue
                if not (AskPriceAtL5Twa >= AskPriceAvgL5Twa):
                    if (np.isnan(AskPriceAtL5Twa) == True) or (np.isnan(AskPriceAvgL5Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL5Twa':str(AskPriceAtL5Twa), 'AskPriceAvgL5Twa':str(AskPriceAvgL5Twa)})
                    continue
                if not (AskPriceAtL10Twa >= AskPriceAvgL10Twa):
                    if (np.isnan(AskPriceAtL10Twa) == True) or (np.isnan(AskPriceAvgL10Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL10Twa':str(AskPriceAtL10Twa), 'AskPriceAvgL10Twa':str(AskPriceAvgL10Twa)})
                    continue
                        
                if not (AskPriceAtL3Twa >= AskPriceVwaL3Twa):
                    if (np.isnan(AskPriceAtL3Twa) == True) or (np.isnan(AskPriceVwaL3Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL3Twa':str(AskPriceAtL3Twa), 'AskPriceVwaL3Twa':str(AskPriceVwaL3Twa)})
                    continue
                if not (AskPriceAtL5Twa >= AskPriceVwaL5Twa):
                    if (np.isnan(AskPriceAtL5Twa) == True) or (np.isnan(AskPriceVwaL5Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL5Twa':str(AskPriceAtL5Twa), 'AskPriceVwaL5Twa':str(AskPriceVwaL5Twa)})
                    continue
                if not (AskPriceAtL10Twa >= AskPriceVwaL10Twa):
                    if (np.isnan(AskPriceAtL5Twa) == True) or (np.isnan(AskPriceVwaL5Twa) == True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'AskPriceAtL10Twa':str(AskPriceAtL10Twa), 'AskPriceVwaL10Twa':str(AskPriceVwaL10Twa)})
                    continue

                m1 = 0.8
                m2 = 1.2
                if not ((PreClosePrice * m1 <= BidPriceAtL1Vwa) & (BidPriceAtL1Vwa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAtL1Vwa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAtL1Vwa/PreClosePrice), 'BidPriceAtL1Vwa':str(BidPriceAtL1Vwa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAtL1Vwa) & (AskPriceAtL1Vwa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAtL1Vwa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAtL1Vwa/PreClosePrice), 'AskPriceAtL1Vwa':str(AskPriceAtL1Vwa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAtL3Twa) & (BidPriceAtL3Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAtL3Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAtL3Twa/PreClosePrice), 'BidPriceAtL3Twa':str(BidPriceAtL3Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAvgL3Twa) & (BidPriceAvgL3Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAvgL3Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL3Twa/PreClosePrice), 'BidPriceAvgL3Twa':str(BidPriceAvgL3Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAvgL3Vwa) & (BidPriceAvgL3Vwa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAvgL3Vwa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL3Vwa/PreClosePrice), 'BidPriceAvgL3Vwa':str(BidPriceAvgL3Vwa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceVwaL3Twa) & (BidPriceVwaL3Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceVwaL3Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceVwaL3Twa/PreClosePrice), 'BidPriceVwaL3Twa':str(BidPriceVwaL3Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAtL3Twa) & (AskPriceAtL3Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAtL3Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAtL3Twa/PreClosePrice), 'AskPriceAtL3Twa':str(AskPriceAtL3Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAvgL3Twa) & (AskPriceAvgL3Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAvgL3Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL3Twa/PreClosePrice), 'AskPriceAvgL3Twa':str(AskPriceAvgL3Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAvgL3Vwa) & (AskPriceAvgL3Vwa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAvgL3Vwa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL3Vwa/PreClosePrice), 'AskPriceAvgL3Vwa':str(AskPriceAvgL3Vwa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceVwaL3Twa) & (AskPriceVwaL3Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceVwaL3Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceVwaL3Twa/PreClosePrice), 'AskPriceVwaL3Twa':str(AskPriceVwaL3Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAtL5Twa) & (BidPriceAtL5Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAtL5Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAtL5Twa/PreClosePrice), 'BidPriceAtL5Twa':str(BidPriceAtL5Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAvgL5Twa) & (BidPriceAvgL5Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAvgL5Twa)==True):
                         continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL5Twa/PreClosePrice), 'BidPriceAvgL5Twa':str(BidPriceAvgL5Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAvgL5Vwa) & (BidPriceAvgL5Vwa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAvgL5Vwa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL5Vwa/PreClosePrice), 'BidPriceAvgL5Vwa':str(BidPriceAvgL5Vwa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceVwaL5Twa) & (BidPriceVwaL5Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceVwaL5Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceVwaL5Twa/PreClosePrice), 'BidPriceVwaL5Twa':str(BidPriceVwaL5Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAtL5Twa) & (AskPriceAtL5Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAtL5Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAtL5Twa/PreClosePrice), 'AskPriceAtL5Twa':str(AskPriceAtL5Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAvgL5Twa) & (AskPriceAvgL5Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAvgL5Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL5Twa/PreClosePrice), 'AskPriceAvgL5Twa':str(AskPriceAvgL5Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAvgL5Vwa) & (AskPriceAvgL5Vwa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAvgL5Vwa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL5Vwa/PreClosePrice), 'AskPriceAvgL5Vwa':str(AskPriceAvgL5Vwa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceVwaL5Twa) & (AskPriceVwaL5Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceVwaL5Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceVwaL5Twa/PreClosePrice), 'AskPriceVwaL5Twa':str(AskPriceVwaL5Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAtL10Twa) & (BidPriceAtL10Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAtL10Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAtL10Twa/PreClosePrice), 'BidPriceAtL10Twa':str(BidPriceAtL10Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAvgL10Twa) & (BidPriceAvgL10Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAvgL10Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL10Twa/PreClosePrice), 'BidPriceAvgL10Twa':str(BidPriceAvgL10Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceAvgL10Vwa) & (BidPriceAvgL10Vwa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceAvgL10Vwa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceAvgL10Vwa/PreClosePrice), 'BidPriceAvgL10Vwa':str(BidPriceAvgL10Vwa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= BidPriceVwaL10Twa) & (BidPriceVwaL10Twa <= PreClosePrice * m2)):
                    if (np.isnan(BidPriceVwaL10Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(BidPriceVwaL10Twa/PreClosePrice), 'BidPriceVwaL10Twa':str(BidPriceVwaL10Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAtL10Twa) & (AskPriceAtL10Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAtL10Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAtL10Twa/PreClosePrice), 'AskPriceAtL10Twa':str(AskPriceAtL10Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAvgL10Twa) & (AskPriceAvgL10Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAvgL10Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL10Twa/PreClosePrice), 'AskPriceAvgL10Twa':str(AskPriceAvgL10Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceAvgL10Vwa) & (AskPriceAvgL10Vwa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceAvgL10Vwa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceAvgL10Vwa/PreClosePrice), 'AskPriceAvgL10Vwa':str(AskPriceAvgL10Vwa), 'PreClosePrice':str(PreClosePrice)})
                    continue
                if not ((PreClosePrice * m1 <= AskPriceVwaL10Twa) & (AskPriceVwaL10Twa <= PreClosePrice * m2)):
                    if (np.isnan(AskPriceVwaL10Twa)==True):
                        continue
                    log.writerow({'secucode':str(new_secucode[i]), 'time':time, 'ratio':str(AskPriceVwaL10Twa/PreClosePrice), 'AskPriceVwaL10Twa':str(AskPriceVwaL10Twa), 'PreClosePrice':str(PreClosePrice)})
                    continue
        os.chdir("../../..")
            
        print('OneDay_log done')
            
            
def main():
    
    for date in range(20200819, 20200822):
        newfolder = "/dat/all_till20201230/Equity/CN/marketdata/level2summary/daily/data/2020/" + str(date) + "/" + str(date) + ".txt"
        oldfolder= "/dat/all_till20201230/Equity/CN/TWAPVWAP/data/2020/" + str(date) + "/" + str(date) + ".txt"
        print(newfolder)
        print(oldfolder)
    
        result = Dataconfirm(newfolder, oldfolder, date)
        result.checkdata()
    
if __name__ == '__main__':
    
    main()
